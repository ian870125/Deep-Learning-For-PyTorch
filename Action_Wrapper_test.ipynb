# %%
import gymnasium as gym
import random
# Out:
# C:\Users\ian\anaconda3\lib\site-packages\gymnasium\envs\registration.py:521: UserWarning: WARN: Overriding environment GymV26Environment-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# C:\Users\ian\anaconda3\lib\site-packages\gymnasium\envs\registration.py:521: UserWarning: WARN: Overriding environment GymV22Environment-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")

# %%
class RandomActionWrapper(gym.ActionWrapper):
    def __init__(self, env, epsilon = 0.1):
        super(RandomActionWrapper, self).__init__(env)
        self.epsilon = epsilon
        
    def action(self, action):
        if random.random() < self.epsilon:
            print("Random!")
            return self.env.action_space.sample()
        return action
    
if __name__ == "__main__":
    env = RandomActionWrapper(gym.make("CartPole-v0"))

    for _ in range(50):
        env.reset()
        total_reward = 0.0
        while True:
            env.render()
            # 固定往左走
            print("往左走!")
            obs, reward, terminated, truncated, info = env.step(0)
            total_reward += reward
            if terminated or truncated:
                break

        print(f"報酬: {total_reward:.2f}")
    env.close()
# Out:
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 報酬: 9.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# Random!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 11.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 8.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 9.00
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 報酬: 10.00
# 往左走!
# 往左走!
# 往左走!
# Random!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# 往左走!
# Random!
# 報酬: 9.00
# C:\Users\ian\anaconda3\lib\site-packages\gymnasium\envs\registration.py:578: UserWarning: WARN: The environment CartPole-v0 is out of date. You should consider upgrading to version `v1`.
#   logger.warn(
# C:\Users\ian\anaconda3\lib\site-packages\gymnasium\envs\classic_control\cartpole.py:212: UserWarning: WARN: You are calling render method without specifying any render mode. You can specify the render_mode at initialization, e.g. gym.make("CartPole-v0", render_mode="rgb_array")
#   gym.logger.warn(

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
image_file = "./images_Object_Detection/lena.jpg"
image = cv2.imread(image_file)

# %%
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
cascade = cv2.CascadeClassifier("./cascade_files/haarcascade_frontalface_alt2.xml")
faces = cascade.detectMultiScale(image , 1.5, 5)
print("faces", faces)
facemark = cv2.face.createFacemarkLBF()
facemark.loadModel("OpenCV/lbfmodel.yaml")
ok, landmarks1 = facemark.fit(image , faces)
print ("landmarks LBF", ok, landmarks1)
# Out:
# faces [[225 205 152 152]]
# landmarks LBF True (array([[[201.31314, 268.08807],
#         [201.5153 , 293.1106 ],
#         [204.91422, 317.07196],
#         [210.71988, 340.4278 ],
#         [222.97098, 360.37122],
#         [240.34521, 375.51422],
#         [260.10678, 386.35587],
#         [280.64197, 392.04227],
#         [298.6573 , 390.89835],
#         [311.434  , 384.88406],
#         [318.37827, 371.23538],
#         [324.82266, 357.113  ],
#         [331.87363, 342.1786 ],
#         [339.7072 , 327.1501 ],
#         [346.04462, 311.9719 ],
#         [349.2847 , 296.59448],
#         [348.95883, 280.12585],
#         [236.43172, 252.06743],
#         [251.37927, 245.06682],
#         [268.54245, 242.64853],
#         [284.97516, 247.29442],
#         [299.09363, 255.40219],
#         [326.43286, 255.8234 ],
#         [334.87848, 249.93437],
#         [343.76285, 246.57608],
#         [352.36066, 246.1333 ],
#         [356.09622, 253.07555],
#         [312.4146 , 268.7993 ],
#         [314.42938, 283.27505],
#         [317.071  , 297.70154],
#         [319.808  , 312.42233],
#         [294.85364, 318.97562],
#         [303.98367, 322.30692],
#         [313.15393, 325.39175],
#         [320.82068, 322.1549 ],
#         [326.67032, 317.0445 ],
#         [253.07791, 267.4625 ],
#         [263.371  , 261.5792 ],
#         [275.39243, 262.03607],
#         [285.0252 , 271.31696],
#         [274.36578, 273.53778],
#         [262.34122, 272.9785 ],
#         [319.47473, 271.6283 ],
#         [328.65216, 262.8718 ],
#         [338.5728 , 262.50098],
#         [344.34396, 268.48907],
#         [339.4144 , 273.34647],
#         [329.61963, 273.5367 ],
#         [269.0964 , 343.3146 ],
#         [287.10745, 340.14523],
#         [302.31882, 337.54327],
#         [309.37003, 339.55722],
#         [315.68216, 337.18167],
#         [321.58014, 338.51422],
#         [325.38004, 341.30286],
#         [319.2977 , 353.2399 ],
#         [313.21277, 359.70975],
#         [306.20355, 361.80457],
#         [298.34967, 361.68167],
#         [284.13876, 356.9431 ],
#         [273.9097 , 344.03867],
#         [301.2978 , 344.25613],
#         [308.60107, 344.5836 ],
#         [314.78738, 343.00418],
#         [322.14587, 343.02502],
#         [313.84515, 348.8564 ],
#         [307.28394, 351.40677],
#         [299.9147 , 351.3407 ]]], dtype=float32),)

# %%
for p in landmarks1[0][0]:
    cv2.circle(image, p.astype(int), 5, (0, 255, 0), -1)
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
facemark = cv2.face.createFacemarkAAM()
facemark.loadModel("OpenCV/aam.xml")
ok, landmarks2 = facemark.fit(image , faces)
print ("Landmarks AAM", ok, landmarks2)
# Out:
# Landmarks AAM True (array([[[226.08101, 244.54762],
#         [231.09694, 260.7153 ],
#         [218.0278 , 271.96198],
#         [235.96924, 282.07126],
#         [255.0106 , 289.26627],
#         [254.34108, 306.0417 ],
#         [268.02826, 290.7257 ],
#         [271.10104, 283.922  ],
#         [282.4268 , 281.04532],
#         [289.2055 , 315.10043],
#         [302.33798, 284.6571 ],
#         [318.24017, 271.21112],
#         [311.90976, 255.91621],
#         [312.34326, 241.22672],
#         [298.42157, 226.958  ],
#         [294.22888, 206.90152],
#         [309.22122, 208.57109],
#         [204.49117, 229.53513],
#         [212.62088, 208.02849],
#         [207.1117 , 221.66689],
#         [214.9499 , 198.71277],
#         [223.32709, 198.07289],
#         [233.95285, 201.53055],
#         [244.70615, 183.8256 ],
#         [254.17233, 179.86957],
#         [266.81848, 199.7889 ],
#         [288.56036, 204.25746],
#         [233.72382, 213.98817],
#         [236.97984, 227.76003],
#         [240.00163, 233.98996],
#         [242.44281, 239.98973],
#         [239.76395, 256.8433 ],
#         [244.77954, 253.69035],
#         [251.25034, 250.03731],
#         [256.48206, 248.10094],
#         [262.78195, 244.88663],
#         [213.1951 , 221.49106],
#         [224.66875, 225.42934],
#         [219.88307, 232.82326],
#         [227.38484, 224.58626],
#         [222.393  , 237.69415],
#         [206.59666, 230.65225],
#         [255.09973, 212.90201],
#         [263.4404 , 216.8004 ],
#         [259.06323, 214.0484 ],
#         [270.8186 , 194.97562],
#         [266.99725, 198.44283],
#         [256.17053, 211.22527],
#         [246.11743, 271.4427 ],
#         [247.49051, 277.2481 ],
#         [253.90607, 263.3915 ],
#         [260.25507, 267.524  ],
#         [262.8949 , 262.9957 ],
#         [275.02936, 265.4811 ],
#         [290.6253 , 253.31544],
#         [278.5716 , 267.6311 ],
#         [268.5421 , 284.13742],
#         [266.76834, 287.97998],
#         [259.24554, 290.12753],
#         [256.12234, 280.3757 ],
#         [243.84966, 281.44452],
#         [258.409  , 268.24637],
#         [262.79816, 276.19116],
#         [264.1688 , 267.56735],
#         [282.52704, 260.05945],
#         [265.77628, 262.56323],
#         [262.40576, 260.88773],
#         [256.44067, 277.9974 ]]], dtype=float32),)

# %%
for p in landmarks2[0][0]:
    cv2.circle(image, tuple(p.astype(int)), 5, (0, 255, 0), -1)
    
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()

# %%
facemark = cv2.face.createFacemarkKazemi()
facemark.loadModel("./OpenCV/face_landmark_model.dat")
ok, landmarks2 = facemark.fit(image , faces)
print ("Landmarks Kazemi", ok, landmarks2)
# Out:
# Landmarks Kazemi True (array([[[216.56874, 266.57913],
#         [215.20233, 291.86505],
#         [215.28194, 316.80167],
#         [217.81096, 341.48755],
#         [226.83978, 361.52377],
#         [241.37547, 376.6876 ],
#         [259.0576 , 387.25168],
#         [279.16473, 394.28555],
#         [296.71255, 394.67337],
#         [310.8934 , 389.2974 ],
#         [321.26428, 377.10483],
#         [330.60757, 363.37103],
#         [336.27756, 347.5388 ],
#         [339.75464, 330.32742],
#         [343.16296, 312.40747],
#         [345.48984, 296.4741 ],
#         [345.66937, 280.78018],
#         [249.11577, 251.51419],
#         [261.6812 , 243.72044],
#         [275.86133, 242.50322],
#         [288.78043, 246.76709],
#         [300.37335, 255.3527 ],
#         [321.86874, 257.9139 ],
#         [328.8085 , 251.00723],
#         [336.09775, 245.99336],
#         [343.42865, 243.8321 ],
#         [349.0863 , 249.0046 ],
#         [309.22806, 271.53445],
#         [310.7499 , 284.7748 ],
#         [312.5577 , 297.79532],
#         [314.41476, 311.18988],
#         [292.6815 , 321.22964],
#         [300.6661 , 324.1542 ],
#         [308.6273 , 327.43973],
#         [315.24234, 324.95465],
#         [319.9542 , 319.97998],
#         [262.20343, 272.99597],
#         [270.56158, 266.9522 ],
#         [279.44583, 267.43378],
#         [285.72275, 275.5236 ],
#         [278.66043, 278.57343],
#         [269.64282, 278.1709 ],
#         [319.11282, 274.77786],
#         [326.88477, 267.0045 ],
#         [334.45132, 265.97586],
#         [339.05988, 272.0655 ],
#         [334.73502, 276.75748],
#         [327.10385, 277.29004],
#         [270.9024 , 349.08737],
#         [285.91837, 344.90372],
#         [298.21454, 342.97815],
#         [303.61694, 343.43478],
#         [308.11664, 341.82895],
#         [313.3309 , 344.0965 ],
#         [318.53436, 349.10477],
#         [312.55276, 353.35886],
#         [307.12192, 355.76736],
#         [302.23834, 356.95377],
#         [296.49377, 357.82413],
#         [284.5872 , 356.66498],
#         [275.50607, 349.17282],
#         [297.72934, 351.6948 ],
#         [303.30908, 350.7966 ],
#         [307.706  , 350.27686],
#         [314.81076, 349.781  ],
#         [307.53888, 345.05856],
#         [303.00467, 346.0945 ],
#         [297.42065, 347.3862 ]]], dtype=float32),)

# %%
for p in landmarks2[0][0]:
    cv2.circle(image, tuple(p.astype(int)), 5, (0, 255, 0), -1)
    
image_RGB = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image_RGB)
plt.axis('off')
plt.show()
